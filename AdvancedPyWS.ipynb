# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("imdb_top_1000.csv")

# %%
print(df.head())
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df['Runtime (Minutes)']
# Out:
# 0      121
# 1      124
# 2      117
# 3      108
# 4      123
#       ...
# 995    111
# 996     94
# 997     98
# 998     93
# 999     87
# Name: Runtime (Minutes), Length: 1000, dtype: int64

# %%
plt.hist(df['Runtime (Minutes)'])
# Out:
# (array([  3.,  78., 256., 268., 208.,  98.,  52.,  26.,   6.,   5.]),
#  array([ 66. ,  78.5,  91. , 103.5, 116. , 128.5, 141. , 153.5, 166. ,
#         178.5, 191. ]),
#  <BarContainer object of 10 artists>)

# %%
std = 0.945429
variance = 0.8938

# %%
print(df.nlargest(n=10, columns='Rating'))
# Out:
#      Rank                  Title                    Genre  \
# 54     55        The Dark Knight       Action,Crime,Drama
# 80     81              Inception  Action,Adventure,Sci-Fi
# 117   118                 Dangal   Action,Biography,Drama
# 36     37           Interstellar   Adventure,Drama,Sci-Fi
# 96     97          Kimi no na wa  Animation,Drama,Fantasy
# 249   250       The Intouchables   Biography,Comedy,Drama
# 64     65           The Prestige     Drama,Mystery,Sci-Fi
# 99    100           The Departed     Crime,Drama,Thriller
# 124   125  The Dark Knight Rises          Action,Thriller
# 133   134               Whiplash              Drama,Music
#
#                                            Description           Director  \
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 117  Former wrestler Mahavir Singh Phogat and his t...      Nitesh Tiwari
# ...

# %%
print(df.nsmallest(n=5, columns='Rating'))
# Out:
#      Rank                    Title                     Genre  \
# 829   830           Disaster Movie                    Comedy
# 42     43  Don't Fuck in the Woods                    Horror
# 871   872     Dragonball Evolution  Action,Adventure,Fantasy
# 647   648                 Tall Men   Fantasy,Horror,Thriller
# 890   891               The Intent               Crime,Drama
#
#                                            Description           Director  \
# 829  Over the course of one evening, an unsuspectin...    Jason Friedberg
# 42   A group of friends are going on a camping trip...      Shawn Burkett
# 871  The young warrior Son Goku sets out on a quest...         James Wong
# 647  A challenged man is stalked by tall phantoms i...  Jonathan Holbrook
# 890  Gunz (Dylan Duffus) is thrust into a world of ...      Femi Oyeniran
#
#                                                 Actors  Year  \
# 829  Carmen Electra, Vanessa Lachey,Nicole Parker, ...  2008
# ...

# %%
print(df[df['Rating'] > 8.5])
# Out:
#      Rank             Title                    Genre  \
# 36     37      Interstellar   Adventure,Drama,Sci-Fi
# 54     55   The Dark Knight       Action,Crime,Drama
# 80     81         Inception  Action,Adventure,Sci-Fi
# 96     97     Kimi no na wa  Animation,Drama,Fantasy
# 117   118            Dangal   Action,Biography,Drama
# 249   250  The Intouchables   Biography,Comedy,Drama
#
#                                            Description           Director  \
# 36   A team of explorers travel through a wormhole ...  Christopher Nolan
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 96   Two strangers find themselves linked in a biza...     Makoto Shinkai
# 117  Former wrestler Mahavir Singh Phogat and his t...      Nitesh Tiwari
# 249  After he becomes a quadriplegic from a paragli...    Olivier Nakache
#
#                                                 Actors  Year  \
# ...

# %%
dfjustnumbers= df['Rating'] #just grab columns that are just numbers 
#then use dfjustnumbers.corr
print('Runtime correlation to Ratings: ',dfjustnumbers.corr(df['Runtime (Minutes)']))
print('Votes correlation to Ratings: ',dfjustnumbers.corr(df['Votes']))
print('Revenue correlation to Ratings: ',dfjustnumbers.corr(df['Revenue (Millions)']))
print('Metascore correlation to Ratings: ',dfjustnumbers.corr(df['Metascore']))
# Out:
# Runtime correlation to Ratings:  0.3922142455250514
# Votes correlation to Ratings:  0.5115373197657558
# Revenue correlation to Ratings:  0.2176538941910601
# Metascore correlation to Ratings:  0.6318965100387067

# %%
ratingandruntime = df[(df['Rating'] > 8.0) & (df['Runtime (Minutes)'] < 100)]
print(ratingandruntime)
# Out:
#      Rank                           Title                       Genre  \
# 154   155  Twin Peaks: The Missing Pieces        Drama,Horror,Mystery
# 238   239        The Grand Budapest Hotel      Adventure,Comedy,Drama
# 241   242                      Inside Out  Animation,Adventure,Comedy
# 478   479                  Paint It Black                       Drama
# 499   500                              Up  Animation,Adventure,Comedy
# 634   635                          WALL·E  Animation,Adventure,Family
# 695   696             Hachi: A Dog's Tale                Drama,Family
# 772   773        How to Train Your Dragon  Animation,Action,Adventure
#
#                                            Description         Director  \
# 154  Twin Peaks before Twin Peaks (1990) and at the...      David Lynch
# 238  The adventures of Gustave H, a legendary conci...     Wes Anderson
# 241  After young Riley is uprooted from her Midwest...      Pete Docter
# ...

# %%
plt.boxplot(df['Rating'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11d559160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x11d559400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x11d559010>],
#  'medians': [<matplotlib.lines.Line2D at 0x11d5596a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11d5597f0>],
#  'means': []}

# %%
groups = df.groupby('Genre')['Rating'].mean()
print(groups)
# Out:
# Genre
# Action                        6.150000
# Action,Adventure              6.400000
# Action,Adventure,Biography    7.000000
# Action,Adventure,Comedy       6.592857
# Action,Adventure,Crime        6.433333
#                                 ...
# Romance,Sci-Fi,Thriller       7.100000
# Sci-Fi                        4.950000
# Sci-Fi,Thriller               5.000000
# Thriller                      5.955556
# Thriller,War                  6.000000
# Name: Rating, Length: 207, dtype: float64

# %%
groups.nlargest(n=10)
# Out:
# Genre
# Animation,Drama,Fantasy       8.60
# Drama,Family,Music            8.50
# Animation,Drama,Romance       8.40
# Drama,Western                 8.40
# Adventure,Drama,Sci-Fi        8.30
# Adventure,Drama,War           8.30
# Biography,Comedy,Crime        8.20
# Drama,Fantasy,War             8.20
# Drama,Mystery,War             8.20
# Animation,Adventure,Family    8.15
# Name: Rating, dtype: float64

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
grouped = df.groupby('Year')['Rating'].mean()
print(grouped)
# Out:
# Year
# 2006    7.125000
# 2007    7.133962
# 2008    6.784615
# 2009    6.960784
# 2010    6.826667
# 2011    6.838095
# 2012    6.925000
# 2013    6.812088
# 2014    6.837755
# 2015    6.602362
# 2016    6.436700
# Name: Rating, dtype: float64

# %%
plt.plot(grouped)
#The trend is that movies have overall been rated lower than in the past

# %%
df['Director'].value_counts()
# Out:
# Director
# Ridley Scott          8
# David Yates           6
# M. Night Shyamalan    6
# Paul W.S. Anderson    6
# Michael Bay           6
#                      ..
# Lee Toland Krieger    1
# Gillies MacKinnon     1
# Peter Atencio         1
# James Mangold         1
# Scot Armstrong        1
# Name: count, Length: 644, dtype: int64

# %%
2*18.810908
# Out:
# 37.621816

# %%
113.172000+37.621816
# Out:
# 150.793816

# %%
print(df[(df['Runtime (Minutes)'] > 150.793816)])
# Out:
#      Rank                                              Title  \
# 26     27                            Bahubali: The Beginning
# 36     37                                       Interstellar
# 54     55                                    The Dark Knight
# 55     56                                            Silence
# 60     61                 Batman v Superman: Dawn of Justice
# 75     76           Pirates of the Caribbean: At World's End
# 77     78                               Inglourious Basterds
# 78     79         Pirates of the Caribbean: Dead Man's Chest
# 82     83                            The Wolf of Wall Street
# 87     88                                             Avatar
# 88     89                                  The Hateful Eight
# 90     91                                          Prisoners
# 99    100                                       The Departed
# 117   118                                             Dangal
# ...

# %%
group_by_genre = df.groupby('Votes')['Genre'].max()
print(group_by_genre)
# Out:
# Votes
# 61                           Drama
# 96                           Drama
# 102                 Comedy,Romance
# 115                    Drama,Sport
# 164                          Drama
#                     ...
# 1045588              Action,Sci-Fi
# 1047747     Adventure,Drama,Sci-Fi
# 1222645            Action,Thriller
# 1583625    Action,Adventure,Sci-Fi
# 1791916         Action,Crime,Drama
# Name: Genre, Length: 997, dtype: object
